# %% [markdown]
# # 네이버 영화 리뷰 감성분석

# %% [markdown]
# 원본 링크 : https://wikidocs.net/44249 (<a href=https://creativecommons.org/licenses/by-nc-sa/2.0/kr/>CC BY-NC-SA 2.0 KR</a>)<br>
# Modified by uramoon@kw.ac.kr

# %% [markdown]
# ## konlpy 설치
# 런타임 유형을 GPU로 설정하세요.

# %%
# 우리말 자연어 처리를 위한 패키지 인스톨
# !pip install konlpy

import tensorflow as tf
import pandas as pd
import urllib.request
import matplotlib.pyplot as plt
import re
from konlpy.tag import Okt
from tqdm import tqdm
from tensorflow.keras.preprocessing.text import Tokenizer
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 60.2 MB/s eta 0:00:00
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading JPype1-1.4.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (465 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.3/465.3 kB 35.5 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.2)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (23.1)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.1 konlpy-0.6.0

# %% [markdown]
# ## 데이터 준비하기

# %% [markdown]
# ### 데이터 다운로드

# %%
# 훈련 데이터와 테스트 데이터 다운로드
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt", filename="ratings_train.txt")
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt", filename="ratings_test.txt")
# Out:
# ('ratings_test.txt', <http.client.HTTPMessage at 0x7f7c6f1e25c0>)

# %%
# 다운받은 훈련 데이터 파일 앞부분 확인, label 0은 부정적 리뷰, 1은 긍정적 리뷰
# !head ratings_train.txt
# Out:
# id	document	label
# 9976970	아 더빙.. 진짜 짜증나네요 목소리	0
# 3819312	흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나	1
# 10265843	너무재밓었다그래서보는것을추천한다	0
# 9045019	교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정	0
# 6483659	사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 던스트가 너무나도 이뻐보였다	1
# 5403919	막 걸음마 뗀 3세부터 초등학교 1학년생인 8살용영화.ㅋㅋㅋ...별반개도 아까움.	0
# 7797314	원작의 긴장감을 제대로 살려내지못했다.	0
# 9443947	별 반개도 아깝다 욕나온다 이응경 길용우 연기생활이몇년인지..정말 발로해도 그것보단 낫겟다 납치.감금만반복반복..이드라마는 가족도없다 연기못하는사람만모엿네	0
# 7156791	액션이 없는데도 재미 있는 몇안되는 영화	1

# %%
# TODO: 다운받은 테스트 데이터 파일 앞부분 확인
# !head ratings_test.txt
# Out:
# id	document	label
# 6270596	굳 ㅋ	1
# 9274899	GDNTOPCLASSINTHECLUB	0
# 8544678	뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아	0
# 6825595	지루하지는 않은데 완전 막장임... 돈주고 보기에는....	0
# 6723715	3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠??	0
# 7898805	음악이 주가 된, 최고의 음악영화	1
# 6315043	진정한 쓰레기	0
# 6097171	마치 미국애니에서 튀어나온듯한 창의력없는 로봇디자인부터가,고개를 젖게한다	0
# 8932678	갈수록 개판되가는 중국영화 유치하고 내용없음 폼잡다 끝남 말도안되는 무기에 유치한cg남무 아 그립다 동사서독같은 영화가 이건 3류아류작이다	0

# %% [markdown]
# ### DataFrame으로 변환
# 데이터를 텍스트 파일보다 다루기 쉬운 DataFrame으로 변환합니다.

# %%
# DataFrame으로 읽기
train_data = pd.read_table('ratings_train.txt')
test_data = pd.read_table('ratings_test.txt')

# %%
# train_data에서 무작위로 5개 샘플링
train_data.sample(5)
# Out:
#             id                                           document  label
# 6126   8468088  일드로도 봤지만 다시보니까 재밌네요.근데 3년만이라 스토리가 기억이잘안나서 더 재밌...      1
# 56307  6312272       평점에 또 속네.영화 보는내내 거부감이 많이 일어난다.영화광들은 추천.그외 비추      0
# 33230  6847337  아직도 적벽에서 조조100만 대군과 맞선 장비의 적벽대전 등을 믿는 사람이 많을거 ...      0
# 38118  4014512                                   이영화 어디에도 사랑은 없다.      0
# 85969  8155079                                     시리즈 또 나왔으몀 좋겠다      1

# %%
# TODO: test_data에서 무작위로 5개 샘플링
test_data.sample(5)
# Out:
#              id                                       document  label
# 4817    9643157                                   남주 여주 예쁘당--/      0
# 36279    117866           ㄹㅇㄴㅁㄹㅇㄴㅁㄹㅇㄴㅁㄹㅇㄴㅁㄹㅇㄴㅁㄹㅇㄴㅁㄹㅇㄴㅁㄹㅇㄴㅁㄹㅇㄴㅁ      1
# 23663  10093558                      슬픈영화보고 우울해서 이거봤는데 빵빵터짐ㅋㅋㅋ      1
# 3620    6028048  이해 못한 놈들은 재미없다고할 영화고, 영화에 빠져든사람은 재밌게봤을영화임....      1
# 38253   4003322                       재밌음ㅋㅋ 나가사와마사미 얘 맘에들었음...      1

# %%
# TODO: 샘플 개수 출력
# Hint: pandas.DataFrame.size 이용
print('훈련 샘플의 개수 :',len(train_data)) # 훈련용 리뷰 개수 출력
print('테스트 샘플의 개수 :',len(test_data)) # 테스트용 리뷰 개수 출력
# Out:
# 훈련 샘플의 개수 : 150000
# 테스트 샘플의 개수 : 50000

# %% [markdown]
# ### 레이블 확인
# 부정적 리뷰와 긍정적 리뷰의 비율을 살펴봅시다.

# %%
# 훈련 데이터
train_data['label'].hist()
# Out:
# <Axes: >

# %%
# TODO: 테스트 데이터 label 분포를 그려보세요.
test_data['label'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ## 리뷰에서 한글과 공백만 남기기

# %%
# train_data 뒷부분 확인
train_data.tail(10)
# Out:
#               id                                           document  label
# 149990   6373651                                       이걸 영화라고 찎었냐?      0
# 149991   9492905  http://blog.naver.com/oroblast/220215679580 나쁜...      1
# 149992   9335962  공포나 재난영화가 아니라 아예 대놓고 비급 크리쳐개그물임ㅋㅋ 음악 완전 흥겹다ㅋ 5...      0
# 149993  10020916                 For Carl.칼 세이건으로 시작해서 칼 세이건으로 끝난다.      1
# 149994   9458520               디케이드 다음에 더블 다음에 오즈인데 더블은 조금밖에 안나오네요.      1
# 149995   6222902                                인간이 문제지.. 소는 뭔죄인가..      0
# 149996   8549745                                      평점이 너무 낮아서...      1
# 149997   9311800                    이게 뭐요? 한국인은 거들먹거리고 필리핀 혼혈은 착하다?      0
# 149998   2376369                        청춘 영화의 최고봉.방황과 우울했던 날들의 자화상      1
# 149999   9619869                           한국 영화 최초로 수간하는 내용이 담긴 영화      0

# %%
# train_data의 document열에서 한글만 남기기, 즉 초성 (ㄱ부터 ㅎ까지), 중성 (ㅏ부터 ㅣ까지), 
# 음절(가부터 힣까지), 공백을 제외한 문자들을 ""로 변환
train_data['document'] = train_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","", regex=True)

# 위와 비교해보세요.
train_data.tail(10)
# Out:
#               id                                           document  label
# 149990   6373651                                        이걸 영화라고 찎었냐      0
# 149991   9492905   나쁜 인상은 아니지만오랫동안 기억에 남아종종 떠올라서조금은 사람을 피곤하게 만드는...      1
# 149992   9335962  공포나 재난영화가 아니라 아예 대놓고 비급 크리쳐개그물임ㅋㅋ 음악 완전 흥겹다ㅋ 점...      0
# 149993  10020916                           칼 세이건으로 시작해서 칼 세이건으로 끝난다      1
# 149994   9458520                디케이드 다음에 더블 다음에 오즈인데 더블은 조금밖에 안나오네요      1
# 149995   6222902                                    인간이 문제지 소는 뭔죄인가      0
# 149996   8549745                                         평점이 너무 낮아서      1
# 149997   9311800                      이게 뭐요 한국인은 거들먹거리고 필리핀 혼혈은 착하다      0
# 149998   2376369                         청춘 영화의 최고봉방황과 우울했던 날들의 자화상      1
# 149999   9619869                           한국 영화 최초로 수간하는 내용이 담긴 영화      0

# %% [markdown]
# ## 공백만 남은 리뷰 제거하기
# 한글이 없었던 리뷰는 공백으로 변했기 때문에 제거합니다.

# %%
train_data['document'] = train_data['document'].str.replace(' +$', "", regex=True) # 공백으로만 이루어진 리뷰를 ""로 변환
train_data['document'].replace('', np.nan, inplace=True) # ""를 nan값으로 변경
print(train_data.isnull().sum()) # nan인 개수 출력
# Out:
# id             0
# document    1260
# label          0
# dtype: int64

# %%
# 훈련 데이터에서 nan값 지우기
train_data = train_data.dropna(how = 'any')
print(len(train_data))
# Out:
# 148740

# %% [markdown]
# ## 테스트 데이터 전처리하기
# 훈련 데이터와 동일하게 처리합니다.

# %%
# TODO: 한글과 공백만 남기기
test_data['document'] = test_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","", regex=True)
# TODO: 공백으로만 이루어진 리뷰 제거하기
test_data['document'] = test_data['document'].str.replace(' +$', "", regex=True)
test_data['document'].replace('', np.nan, inplace=True)
test_data = test_data.dropna(how = 'any')
print(len(test_data))
# Out:
# 49575

# %% [markdown]
# ## 형태소 분석
# 우리말은 영어와는 달리 공백만으로 단어를 완벽하게 분리해낼 수 없기 때문에 Okt (Open-korean-text)라는 형태소 분석기를 사용할 것입니다.<br>
# Okt는 트위터에서 만든 오픈소스 한국어 처리기인 twitter-korean-text에서 파생됐습니다.

# %%
okt = Okt()

# 자연어처리에 사용하지 않을 불용어는 정의하기 나름인데 아래의 것들만 사용하겠습니다.
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# %%
# 훈련 데이터 형태소 분석
X_train = []
for sentence in tqdm(train_data['document']): # document에서 리뷰 하나씩 가져오기, tqdm이 진행률을 보여줍니다.
    tokenized_sentence = okt.morphs(sentence, stem=True) # 하나의 리뷰 형태소 분석
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어를 제거
    X_train.append(stopwords_removed_sentence) # X_train에 형태소 분석한 리뷰 추가하기
# Out:
# 100%|██████████| 148740/148740 [10:41<00:00, 231.91it/s]

# %%
# 형태소 분석 전후 비교
print(train_data['document'][:5])
np.array(X_train[:5], dtype=object)
# Out:
# 0                                    아 더빙 진짜 짜증나네요 목소리
# 1                           흠포스터보고 초딩영화줄오버연기조차 가볍지 않구나
# 2                                    너무재밓었다그래서보는것을추천한다
# 3                            교도소 이야기구먼 솔직히 재미는 없다평점 조정
# 4    사이몬페그의 익살스런 연기가 돋보였던 영화스파이더맨에서 늙어보이기만 했던 커스틴 던...
# Name: document, dtype: object
# array([list(['아', '더빙', '진짜', '짜증나다', '목소리']),
#        list(['흠', '포스터', '보고', '초딩', '영화', '줄', '오버', '연기', '조차', '가볍다', '않다']),
#        list(['너', '무재', '밓었', '다그', '래서', '보다', '추천', '다']),
#        list(['교도소', '이야기', '구먼', '솔직하다', '재미', '없다', '평점', '조정']),
#        list(['사이', '몬페', '그', '익살스럽다', '연기', '돋보이다', '영화', '스파이더맨', '에서', '늙다', '보이다', '커스틴', '던스트', '너무나도', '이쁘다', '보이다'])],
#       dtype=object)

# %%
X_test = []
# TODO: 테스트 데이터의 형태소를 분석하여 X_test에 저장하세요.
for sentence in tqdm(test_data['document']):
    tokenized_sentence = okt.morphs(sentence, stem=True) 
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords]
    X_test.append(stopwords_removed_sentence)
# Out:
# 100%|██████████| 49575/49575 [03:53<00:00, 212.37it/s]

# %% [markdown]
# ## 토큰화

# %%
# 10,000개의 단어만 사용해봅니다.
num_words = 10000

# TODO: X_train과 X_test 데이터를 합쳐서 적용합니다.
# Hint: 기존 NLP 노트북의 Tokenizer 참조
tokenizer = Tokenizer(num_words=num_words)
tokenizer.fit_on_texts(X_train + X_test)

# %%
# 단어별 인덱스
print(tokenizer.word_index)
# Out:
# {'영화': 1, '보다': 2, '을': 3, '없다': 4, '이다': 5, '있다': 6, '좋다': 7, '너무': 8, '다': 9, '정말': 10, '재밌다': 11, '되다': 12, '만': 13, '적': 14, '진짜': 15, '같다': 16, '로': 17, '아니다': 18, '않다': 19, '점': 20, '에서': 21, '만들다': 22, '나오다': 23, '평점': 24, '연기': 25, '것': 26, '최고': 27, '내': 28, '그': 29, '나': 30, '인': 31, '안': 32, '생각': 33, '못': 34, '스토리': 35, '왜': 36, '드라마': 37, '게': 38, '감동': 39, '사람': 40, '보고': 41, '이렇다': 42, '아깝다': 43, '말': 44, '고': 45, '더': 46, '때': 47, 'ㅋㅋ': 48, '배우': 49, '감독': 50, '아': 51, '재미있다': 52, '그냥': 53, '거': 54, '요': 55, '재미': 56, '시간': 57, '내용': 58, '까지': 59, '중': 60, '주다': 61, '뭐': 62, '재미없다': 63, '자다': 64, '하고': 65, '지루하다': 66, '쓰레기': 67, '수': 68, '네': 69, '가다': 70, '들다': 71, '모르다': 72, '그렇다': 73, '싶다': 74, '지': 75, '사랑': 76, '작품': 77, '알다': 78, '볼': 79, '다시': 80, '하나': 81, '마지막': 82, '이건': 83, '저': 84, '정도': 85, 'ㅠㅠ': 86, '오다': 87, 'ㅋ': 88, '완전': 89, '많다': 90, '처음': 91, 'ㅋㅋㅋ': 92, '장면': 93, '액션': 94, '주인공': 95, '이렇게': 96, '안되다': 97, '걸': 98, '차다': 99, '나다': 100, '최악': 101, '하': 102, '개': 103, '이야기': 104, '지금': 105, '돈': 106, '별로': 107, 'ㅡㅡ': 108, '임': 109, '넘다': 110, '연출': 111, '느낌': 112, '끝': 113, '좋아하다': 114, '라': 115, '인데': 116, '듯': 117, '명작': 118, '년': 119, '기': 120, '역시': 121, '그리고': 122, '받다': 123, '많이': 124, '별': 125, '남다': 126, '이해': 127, '난': 128, '면': 129, '이런': 130, '괜찮다': 131, '분': 132, '라고': 133, '이영화': 134, '느끼다': 135, '버리다': 136, '때문': 137, '서': 138, '또': 139, '여자': 140, '이나': 141, '부터': 142, '성': 143, '아름답다': 144, '해주다': 145, '일': 146, '먹다': 147, '꼭': 148, '두': 149, '보기': 150, '에게': 151, '이고': 152, '짱': 153, '무슨': 154, '여': 155, '대': 156, '엔': 157, '기억': 158, '편': 159, '인생': 160, '결말': 161, '마음': 162, 'ㅎㅎ': 163, '랑': 164, '전': 165, '야': 166, '영': 167, '보여주다': 168, '뻔하다': 169, '애': 170, '아쉽다': 171, '어떻다': 172, '끄다': 173, '님': 174, '수준': 175, '소재': 176, '어리다': 177, '무섭다': 178, '없이': 179, '재다': 180, '맞다': 181, '현실': 182, '한번': 183, '속': 184, '제': 185, '반전': 186, '웃기다': 187, '씨': 188, '매력': 189, '되어다': 190, '본': 191, '끝나다': 192, '전개': 193, '가슴': 194, '급': 195, '라는': 196, '남자': 197, '한국': 198, '가장': 199, '말다': 200, '슬프다': 201, '낮다': 202, '아이': 203, '뿐': 204, '높다': 205, '죽다': 206, '멋지다': 207, '알': 208, '니': 209, '유치하다': 210, '다른': 211, '음악': 212, '크다': 213, '인간': 214, '냐': 215, '화': 216, '줄': 217, '솔직하다': 218, '원작': 219, '추천': 220, '눈물': 221, '우리': 222, '쓰다': 223, '번': 224, '함': 225, '늘다': 226, '살다': 227, '모든': 228, '자체': 229, '인지': 230, '내다': 231, '지만': 232, '야하다': 233, '허다': 234, '하지만': 235, '눈': 236, '찍다': 237, '인가': 238, '캐릭터': 239, '코미디': 240, '모두': 241, '대한': 242, '처럼': 243, '대박': 244, 'ㅋㅋㅋㅋ': 245, '보이다': 246, '뭔가': 247, '돼다': 248, 'ㅠ': 249, '연기력': 250, '짜증나다': 251, '이상': 252, '이쁘다': 253, '건지다': 254, '이네': 255, '기대하다': 256, '그래도': 257, '모습': 258, '미치다': 259, '여운': 260, '시리즈': 261, '움': 262, '개봉': 263, '전혀': 264, '지다': 265, '기대': 266, '공감': 267, '중간': 268, '표현': 269, '에는': 270, '일본': 271, '계속': 272, '굿': 273, '부분': 274, '치다': 275, '근데': 276, '아주': 277, '영상': 278, '실망': 279, '이라': 280, 'ㅜㅜ': 281, '시키다': 282, '작': 283, '이랑': 284, '제목': 285, '가족': 286, '진심': 287, '보지': 288, '내내': 289, '뭔': 290, '이제': 291, '귀엽다': 292, '기분': 293, '짜다': 294, '대단하다': 295, '믿다': 296, '몰입': 297, '연': 298, '밖에': 299, 'ㅎ': 300, '후': 301, '건': 302, '작가': 303, '잔잔하다': 304, '떨어지다': 305, '이라는': 306, '요즘': 307, '공포': 308, '감': 309, '빠지다': 310, '웃다': 311, '용': 312, '시': 313, '위': 314, '긴장감': 315, '점도': 316, '잼': 317, '스릴러': 318, '대사': 319, '애니': 320, '극장': 321, '개인': 322, '조금': 323, '특히': 324, '이상하다': 325, '울다': 326, '삶': 327, '이유': 328, '노잼': 329, '노래': 330, '한테': 331, '알바': 332, '욕': 333, '딱': 334, '깊다': 335, '나름': 336, '시작': 337, '놈': 338, '이란': 339, '잇다': 340, '제대로': 341, '오랜': 342, '점수': 343, '예쁘다': 344, '이지': 345, '에도': 346, '차라리': 347, '느껴지다': 348, '막장': 349, '친구': 350, '제일': 351, '따뜻하다': 352, '해보다': 353, '의미': 354, '당시': 355, '극': 356, '영화로': 357, '어설프다': 358, '빼다': 359, '명': 360, '식': 361, '력': 362, '몇': 363, '훌륭하다': 364, '같이': 365, '공포영화': 366, '세상': 367, '절대': 368, '아직도': 369, '이라고': 370, '찾다': 371, '년대': 372, '위해': 373, '웃음': ...

# %%
# 단어별 등장횟수
print(tokenizer.word_counts.items())
# Out:
# odict_items([('아', 5528), ('더빙', 772), ('진짜', 11270), ('짜증나다', 1382), ('목소리', 517), ('흠', 327), ('포스터', 751), ('보고', 6188), ('초딩', 571), ('영화', 67908), ('줄', 1612), ('오버', 202), ('연기', 8489), ('조차', 332), ('가볍다', 479), ('않다', 10284), ('너', 875), ('무재', 85), ('밓었', 1), ('다그', 104), ('래서', 25), ('보다', 54956), ('추천', 1601), ('다', 13589), ('교도소', 27), ('이야기', 2920), ('구먼', 14), ('솔직하다', 1607), ('재미', 5238), ('없다', 20944), ('평점', 8537), ('조정', 51), ('사이', 281), ('몬페', 2), ('그', 7606), ('익살스럽다', 11), ('돋보이다', 391), ('스파이더맨', 81), ('에서', 9313), ('늙다', 259), ('보이다', 1395), ('커스틴', 6), ('던스트', 3), ('너무나도', 282), ('이쁘다', 1375), ('막', 426), ('걸음', 28), ('마', 304), ('떼다', 207), ('세', 781), ('부터', 2307), ('초등학교', 146), ('학년', 159), ('생인', 8), ('살다', 1573), ('ㅋㅋㅋ', 3261), ('별', 2568), ('반개', 283), ('아깝다', 6022), ('움', 1356), ('원작', 1606), ('긴장감', 1111), ('을', 30959), ('제대로', 1024), ('살리다', 715), ('욕', 1046), ('나오다', 8576), ('이응경', 8), ('길용우', 4), ('연', 1193), ('기', 2657), ('생활', 171), ('몇', 946), ('년', 2673), ('인지', 1536), ('정말', 12995), ('발', 433), ('로', 10488), ('해도', 606), ('그것', 620), ('보단', 672), ('낫다', 743), ('납치', 64), ('감금', 14), ('만', 11690), ('반복', 200), ('드라마', 6710), ('가족', 1251), ('못', 7041), ('사람', 6478), ('모', 464), ('엿', 276), ('네', 4541), ('액션', 3178), ('있다', 16599), ('안되다', 3084), ('왜케', 187), ('낮다', 1773), ('꽤', 635), ('볼', 3822), ('데', 895), ('헐리우드', 188), ('식', 954), ('화려하다', 516), ('너무', 14891), ('길들이다', 31), ('인피니트', 35), ('짱', 2134), ('이다', 17735), ('볼때', 431), ('마다', 880), ('눈물나다', 243), ('죽다', 1734), ('년대', 927), ('향수', 92), ('극', 978), ('허진호', 7), ('감성', 553), ('절제', 86), ('멜로', 409), ('달인', 29), ('울면', 112), ('서', 2350), ('손', 366), ('고', 5982), ('횡단보도', 1), ('건너다', 12), ('때', 5798), ('뛰다', 236), ('치다', 1308), ('올', 342), ('뻔', 415), ('이범수', 47), ('드럽다', 311), ('담백하다', 88), ('깔끔하다', 227), ('좋다', 16180), ('신', 746), ('문', 248), ('사', 453), ('로만', 184), ('자꾸', 355), ('잊어버리다', 23), ('것', 8430), ('취향', 362), ('존중', 51), ('다지', 21), ('내생', 143), ('극장', 1087), ('중', 5066), ('가장', 1784), ('노잼', 1056), ('노', 305), ('감동', 6516), ('임', 2797), ('스토리', 7031), ('어거지', 103), ('ㄱ', 143), ('냥', 244), ('매번', 86), ('긴장', 198), ('되다', 11919), ('재밋음', 114), ('ㅠㅠ', 3381), ('차다', 3067), ('웃기다', 1840), ('바스코', 20), ('이기', 216), ('면', 2514), ('락스', 17), ('코', 538), ('라고', 2426), ('끄다', 1982), ('바비', 31), ('아이돌', 198), ('이라고', 931), ('깔다', 269), ('안달', 34), ('난', 2520), ('처럼', 1409), ('굿바이', 28), ('레닌', 6), ('표절', 230), ('인', 7368), ('이해', 2540), ('왜', 6833), ('뒤', 724), ('갈수록', 701), ('없어지다', 175), ('이건', 3481), ('깨알', 91), ('캐스팅', 746), ('질퍽', 5), ('하', 2977), ('지', 4021), ('산뜻하다', 21), ('내', 7939), ('용구성', 8), ('자다', 4875), ('버무러진', 4), ('일드', 46), ('약탈', 9), ('위', 1114), ('변명', 36), ('이르다', 519), ('저', 3436), ('놈', 1034), ('착하다', 291), ('절대', 935), ('아니다', 10430), ('걸', 3072), ('요', 5334), ('나름', 1038), ('심오하다', 138), ('뜻', 238), ('듯', 2714), ('그냥', 5434), ('학생', 187), ('선생', 89), ('놀다', 145), ('웃다', 1121), ('건', 1172), ('불가능하다', 68), ('재미없다', 4890), ('지루하다', 4722), ('같다', 11171), ('음식', 108), ('인데', 2720), ('바베트', 1), ('만찬', 11), ('하고', 4732), ('넘다', 2797), ('차이', 216), ('남바', 1), ('베트', 3), ('게', 6708), ('별로', 2834), ('안', 7354), ('핀란드', 10), ('풍경', 166), ('이라도', 509), ('구', 796), ('경', 178), ('할랫', 1), ('늘다', 1576), ('ㅡㅡ', 2804), ('평범하다', 387), ('수작', 844), ('이라', 1274), ('는걸', 244), ('말씀드리다', 9), ('주제', 521), ('중반', 374), ('짤랐을꺼', 1), ('야', 2057), ('그래서', 641), ('납득', 72), ('수', 4553), ('그렇다', 4137), ('꼭', 2188), ('고추', 21), ('털다', 32), ('버리다', 2366), ('카밀라', 12), ('벨', 73), ('발연기', 568), ('재밋는뎅', 1), ('센스', 113), ('연출', 2783), ('력', 954), ('탁월하다', 87), ('점', 10184), ('엄포스', 3), ('위력', 15), ('다시', 3771), ('한번', 1878), ('깨닫다', 192), ('해주다', 2242), ('적남', 1), ('꽃', 109), ('검사', 72), ('님', 1975), ('완전', 3353), ('명품', 182), ('졸', 113), ('쓰레기', 4660), ('진부하다', 704), ('도안', 175), ('돼다', 1384), ('ㅋㅋ', 5702), ('아시', 63), ('간', 694), ('재밌다', 12104), ('이리', 607), ('라도', 549), ('기대하다', 1367), ('죄인', 17), ('아직도', 935), ('인생', 2095), ('최고', 8 ...

# %%
# 훈련 데이터 토큰화하기
X_train = tokenizer.texts_to_sequences(X_train)

# %%
# TODO: 테스트 데이터 토큰화하기
X_test = tokenizer.texts_to_sequences(X_test)

# %%
# TODO: y값 설정하기, NumPy 배열로 만드세요.
# Hint: DataFrame에서 label 열을 가져오세요.
y_train = np.array(train_data['label'])
y_test = np.array(test_data['label'])

# %% [markdown]
# ## 훈련 데이터에서 리뷰 길이 알아보기
# 인공신경망에 입력할 리뷰의 적정 길이를 알아봅시다.

# %%
# 각 리뷰에 단어 (토큰)가 몇 개씩 들어있는지 세어봅시다.
num_tokens = []

# TODO: num_tokens에 각 리뷰의 단어 숫자를 저장하세요.
# Hint: X_train[0]은 첫 번째 훈련 데이터의 단어들이 저장되어 있습니다. 그 길이는 len 함수로 알 수 있습니다.
for token in X_train:
  num_tokens.append(len(token))

for token in X_test:
  num_tokens.append(len(token))

# %%
# TODO: num_tokens 리스트를 num_tokens NumPy 배열로 변환하세요.
num_tokens = np.array(num_tokens)

# %%
# 모든 리뷰에서 사용한 평균 단어의 수는 다음과 같습니다.
np.mean(num_tokens)
# Out:
# 10.30785870962862

# %%
# TODO: num_tokens에서 평균 + 2 * 표준편차를 구하여 우리가 허용할 최대 단어의 개수인 max_tokens를 설정해보세요.
# num_tokens가 정규분포를 따른다면 97% 이상이 max_tokens보다 적은 단어만을 사용할 것입니다.
# Hint: np.mean과 np.std 사용

max_tokens = np.mean(num_tokens)+3*np.std(num_tokens)
max_tokens = int(max_tokens)
max_tokens
# Out:
# 36

# %%
# max_tokens보다 짧은 리뷰의 비율을 출력하는 코드
# 너무 적다고 생각되면 위에서 3 * 표준편차로 수정해보세요.
np.sum(num_tokens < max_tokens) / len(num_tokens)
# Out:
# 0.9689736026019212

# %%
# 전체 데이터의 길이를 max_tokens로 맞춘다.
# 기본이 'pre'로 설정되어 있습니다. 
X_train = pad_sequences(X_train, maxlen=max_tokens)
X_test = pad_sequences(X_test, maxlen=max_tokens)

# %% [markdown]
# ## 모델 생성

# %%
from tensorflow.keras.layers import Embedding, Dense, LSTM, GRU
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping

# TODO: 자유롭게 설정하세요.
embedding_size = 150 # 일반적으로 100에서 300
es = EarlyStopping(patience=5, restore_best_weights=True)

# %%
model = Sequential()
# 임베딩층 추가
model.add(Embedding(input_dim=num_words,      # 사용하는 단어의 개수
                    output_dim=embedding_size,# 임베딩 차원
                    input_length=max_tokens,  # 리뷰의 길이
                    name='layer_embedding'))

# %%
# TODO: 자유롭게 생성하세요.
model.add(LSTM(256)) # GRU나 LSTM 사용 (여기에서는 LSTM이 좀 더 좋은 성능을 보이는 것 같음)
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])

# %%
# 모델 훈련하기
model.fit(X_train, y_train, epochs=10000, callbacks=es, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/10000
# 1860/1860 [==============================] - 53s 26ms/step - loss: 0.3827 - acc: 0.8255 - val_loss: 0.3404 - val_acc: 0.8520
# Epoch 2/10000
# 1860/1860 [==============================] - 17s 9ms/step - loss: 0.3037 - acc: 0.8686 - val_loss: 0.3350 - val_acc: 0.8565
# Epoch 3/10000
# 1860/1860 [==============================] - 18s 9ms/step - loss: 0.2635 - acc: 0.8870 - val_loss: 0.3494 - val_acc: 0.8551
# Epoch 4/10000
# 1860/1860 [==============================] - 15s 8ms/step - loss: 0.2264 - acc: 0.9050 - val_loss: 0.3656 - val_acc: 0.8492
# Epoch 5/10000
# 1860/1860 [==============================] - 15s 8ms/step - loss: 0.1886 - acc: 0.9233 - val_loss: 0.4158 - val_acc: 0.8437
# Epoch 6/10000
# 1860/1860 [==============================] - 15s 8ms/step - loss: 0.1551 - acc: 0.9382 - val_loss: 0.5043 - val_acc: 0.8460
# Epoch 7/10000
# 1860/1860 [==============================] - 15s 8ms/step - loss: 0.1252 - acc: 0.9499 - val_loss: 0.5436 - val_acc: 0.8411

# %%
# TODO: 테스트 데이터로 평가하기
# 85% 이상을 목표로 합시다.
model.evaluate(X_test, y_test)
# Out:
# 1550/1550 [==============================] - 6s 4ms/step - loss: 0.3443 - acc: 0.8502
# [0.3442988097667694, 0.8502269387245178]

# %% [markdown]
# ## 새로운 리뷰 예측해보기

# %%
# 문자열을 입력하면 위에서 만든 model을 이용해 부정인지 긍정인지 예측해주는 함수

def sentiment_predict(new_sentence):
  new_sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','', new_sentence) # 한글과 공백만 남기기
  new_sentence = okt.morphs(new_sentence, stem=True) # 형태소 분석
  new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
  encoded = tokenizer.texts_to_sequences([new_sentence]) # 토큰화
  pad_new = pad_sequences(encoded, maxlen = max_tokens) # 패딩
  score = float(model.predict(pad_new)) # 예측
  if(score > 0.5):
    print("{:.2f}% 확률로 긍정 리뷰입니다.\n".format(score * 100))
  else:
    print("{:.2f}% 확률로 부정 리뷰입니다.\n".format((1 - score) * 100))

# %%
sentiment_predict('이 영화 개꿀잼 ㅋㅋㅋ')
# Out:
# 1/1 [==============================] - 1s 543ms/step
# 89.77% 확률로 긍정 리뷰입니다.

# %%
sentiment_predict('이 영화 핵노잼 ㅠㅠ')
# Out:
# 1/1 [==============================] - 0s 18ms/step
# 97.98% 확률로 부정 리뷰입니다.

# %%
sentiment_predict('이딴게 영화냐 ㅉㅉ')
# Out:
# 1/1 [==============================] - 0s 18ms/step
# 99.25% 확률로 부정 리뷰입니다.

# %%
sentiment_predict('감독 뭐하는 놈이냐?')
# Out:
# 1/1 [==============================] - 0s 20ms/step
# 98.46% 확률로 부정 리뷰입니다.

# %%
sentiment_predict('와 개쩐다 정말 세계관 최강자들의 영화다')
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 66.14% 확률로 긍정 리뷰입니다.
